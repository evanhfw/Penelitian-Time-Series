# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# from XGBoost import XGBoostRegressor
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor

# %%
data = pd.read_csv('data/data.csv')
data
# Out:
#        Year  Month  Day  Hour  Week  Consumption
# 0      2022      1    1     1    52    10632.430
# 1      2022      1    1     2    52    10293.919
# 2      2022      1    1     3    52    10054.002
# 3      2022      1    1     4    52     9923.824
# 4      2022      1    1     5    52     9874.103
# ...     ...    ...  ...   ...   ...          ...
# 17515  2023     12   31    20    52    12624.528
# 17516  2023     12   31    21    52    12582.705
# 17517  2023     12   31    22    52    12474.459
# 17518  2023     12   31    23    52    12752.635
# 17519  2023     12   31    24    52    12715.336
#
# [17520 rows x 6 columns]

# %%
X = data.drop(['Consumption'], axis=1)
y = data[['Consumption']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=31*24, shuffle=False)

# %%
model = XGBRegressor(random_state=42, n_estimators=100000, early_stopping_rounds=1000, eval_set=[(X_test, y_test)], eval_metric='mape')
model.fit(X_train, y_train, eval_set=[(X_test, y_test)])
# Out:
# [0]	validation_0-mape:0.14076
# [1]	validation_0-mape:0.11507
# [2]	validation_0-mape:0.10199
# [3]	validation_0-mape:0.08952
# [4]	validation_0-mape:0.08223
# [5]	validation_0-mape:0.07954
# [6]	validation_0-mape:0.07882
# [7]	validation_0-mape:0.07659
# [8]	validation_0-mape:0.07632
# [9]	validation_0-mape:0.07529
# [10]	validation_0-mape:0.07505
# [11]	validation_0-mape:0.07403
# [12]	validation_0-mape:0.07328
# [13]	validation_0-mape:0.07292
# [14]	validation_0-mape:0.07221
# [15]	validation_0-mape:0.07041
# [16]	validation_0-mape:0.07046
# [17]	validation_0-mape:0.07042
# [18]	validation_0-mape:0.07040
# [19]	validation_0-mape:0.07059
# [20]	validation_0-mape:0.07161
# [21]	validation_0-mape:0.07146
# [22]	validation_0-mape:0.06417
# [23]	validation_0-mape:0.06419
# [24]	validation_0-mape:0.06419
# [25]	validation_0-mape:0.06347
# [26]	validation_0-mape:0.06350
# [27]	validation_0-mape:0.06168
# [28]	validation_0-mape:0.06195
# [29]	validation_0-mape:0.06183
# ...

# %%
pd.Series(model.predict(X_test)).to_excel('prediction.xlsx')
